# %% [markdown]
# # Install packages
# List of packages that work for the code
# *   https://github.com/saeed-anwar/DRLN/issues/12

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall --y torchvision
# !pip uninstall --y torch
# !pip uninstall --y scipy
# !pip install -q torch==1.1.0 torchvision==0.3.0
# !pip install scipy==1.1.0 # https://github.com/saeed-anwar/DRLN/issues/11
# Out:
# Uninstalling torchvision-0.9.1+cu101:
#   Successfully uninstalled torchvision-0.9.1+cu101
# Uninstalling torch-1.8.1+cu101:
#   Successfully uninstalled torch-1.8.1+cu101
# Uninstalling scipy-1.4.1:
#   Successfully uninstalled scipy-1.4.1
#      |████████████████████████████████| 676.9MB 25kB/s
#      |████████████████████████████████| 2.6MB 46.8MB/s
# ERROR: fastai 1.0.61 requires scipy, which is not installed.
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.1.0 which is incompatible.
# Collecting scipy==1.1.0
#   Downloading https://files.pythonhosted.org/packages/40/de/0c22c6754370ba6b1fa8e53bd6e514d4a41a181125d405a501c215cbdbd6/scipy-1.1.0-cp37-cp37m-manylinux1_x86_64.whl (31.2MB)
#      |████████████████████████████████| 31.2MB 1.4MB/s
# Requirement already satisfied: numpy>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from scipy==1.1.0) (1.19.5)
# ERROR: plotnine 0.6.0 has requirement scipy>=1.2.0, but you'll have scipy 1.1.0 which is incompatible.
# ERROR: albumentations 0.1.12 has requirement imgaug<0.2.7,>=0.2.5, but you'll have imgaug 0.2.9 which is incompatible.
# Installing collected packages: scipy
# Successfully installed scipy-1.1.0

# %%
import torch
print(torch.__version__)
# Out:
# 1.1.0

# %% [markdown]
# # Download code

# %%
# !git clone https://github.com/Luxi-Zhao/SingleImageSuperResolution.git
# Out:
# Cloning into 'SingleImageSuperResolution'...
# remote: Enumerating objects: 340, done.
# remote: Counting objects: 100% (340/340), done.
# remote: Compressing objects: 100% (227/227), done.
# remote: Total 340 (delta 150), reused 283 (delta 93), pack-reused 0
# Receiving objects: 100% (340/340), 16.96 MiB | 11.12 MiB/s, done.
# Resolving deltas: 100% (150/150), done.

# %% [markdown]
# # Download DIV2K

# %%
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X2.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X2.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# !wget http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Out:
# --2021-04-13 12:55:35--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X2.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X2.zip [following]
# --2021-04-13 12:55:35--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_LR_bicubic_X2.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 925390592 (883M) [application/zip]
# Saving to: ‘DIV2K_train_LR_bicubic_X2.zip’
#
# DIV2K_train_LR_bicu 100%[===================>] 882.52M   196MB/s    in 4.6s
#
# 2021-04-13 12:55:40 (192 MB/s) - ‘DIV2K_train_LR_bicubic_X2.zip’ saved [925390592/925390592]
#
# --2021-04-13 12:55:40--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X2.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X2.zip [following]
# --2021-04-13 12:55:40--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_LR_bicubic_X2.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 117763600 (112M) [application/zip]
# Saving to: ‘DIV2K_valid_LR_bicubic_X2.zip’
#
# DIV2K_valid_LR_bicu 100%[===================>] 112.31M   151MB/s    in 0.7s
#
# 2021-04-13 12:55:41 (151 MB/s) - ‘DIV2K_valid_LR_bicubic_X2.zip’ saved [117763600/117763600]
#
# --2021-04-13 12:55:41--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip [following]
# --2021-04-13 12:55:41--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_train_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3530603713 (3.3G) [application/zip]
# Saving to: ‘DIV2K_train_HR.zip’
#
# DIV2K_train_HR.zip  100%[===================>]   3.29G   100MB/s    in 37s
#
# 2021-04-13 12:56:19 (89.9 MB/s) - ‘DIV2K_train_HR.zip’ saved [3530603713/3530603713]
#
# --2021-04-13 12:56:19--  http://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Resolving data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)... 129.132.52.178, 2001:67c:10ec:36c2::178
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:80... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip [following]
# --2021-04-13 12:56:19--  https://data.vision.ee.ethz.ch/cvl/DIV2K/DIV2K_valid_HR.zip
# Connecting to data.vision.ee.ethz.ch (data.vision.ee.ethz.ch)|129.132.52.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 448993893 (428M) [application/zip]
# Saving to: ‘DIV2K_valid_HR.zip’
#
# DIV2K_valid_HR.zip  100%[===================>] 428.19M  71.3MB/s    in 6.8s
#
# 2021-04-13 12:56:26 (63.2 MB/s) - ‘DIV2K_valid_HR.zip’ saved [448993893/448993893]

# %%
# !mkdir DIV2K
# !unzip -q DIV2K_valid_LR_bicubic_X2.zip -d DIV2K
# !unzip -q DIV2K_train_LR_bicubic_X2.zip -d DIV2K
# !unzip -q DIV2K_train_HR.zip -d DIV2K
# !unzip -q DIV2K_valid_HR.zip -d DIV2K

# %%
mv DIV2K/DIV2K_valid_HR/* DIV2K/DIV2K_train_HR/

# %%
mv DIV2K/DIV2K_valid_LR_bicubic/X2/* DIV2K/DIV2K_train_LR_bicubic/X2/

# %% [markdown]
# # Train model

# %%
GDRIVE = '/content/drive/MyDrive/2516'
experiment_name = 'RDN_50epoch_AblateCMLRL_Bicubic'
CODE_DIR = '/content/SingleImageSuperResolution/TestCode' 
first_run = True
data_prep = 'sep_reset' if first_run else 'sep'

# %%
mkdir {GDRIVE}/{experiment_name}

# %%
cd {CODE_DIR}/code
# Out:
# /content/SingleImageSuperResolution/TestCode/code

# %%
# !git checkout rdn-ablate-cm-lrl
# Out:
# Branch 'rdn-ablate-cm-lrl' set up to track remote branch 'rdn-ablate-cm-lrl' from 'origin'.
# Switched to a new branch 'rdn-ablate-cm-lrl'

# %%
# !python main.py --ext_save_path {GDRIVE}/{experiment_name} --save_model_every 10 --RDNconfig C --dir_data ../../.. --ext {data_prep} --scale 2 --model RDN --epochs 50 --patch_size 32 --chop --save {experiment_name}
# Out:
# Preparing seperated binary files
# Preparing seperated binary files
# Making model...
# Preparing loss function:
# 1.000 * L1
# [Epoch 1]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 28.7918]	14.6+0.3s
# [3200/16000]	[L1: 19.5760]	14.4+0.0s
# [4800/16000]	[L1: 15.6242]	14.6+0.0s
# [6400/16000]	[L1: 13.5504]	14.6+0.0s
# [8000/16000]	[L1: 12.1738]	14.6+0.0s
# [9600/16000]	[L1: 11.1760]	14.5+0.0s
# [11200/16000]	[L1: 10.3932]	14.4+0.0s
# [12800/16000]	[L1: 9.7808]	14.5+0.0s
# [14400/16000]	[L1: 9.2998]	14.4+0.0s
# [16000/16000]	[L1: 8.9310]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.63s/it]
# [DIV2K x2]	PSNR: 34.418 (Best: 34.418 @epoch 1)
# Total time: 46.31s, ave time: 4.63s
#
# [Epoch 2]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 5.1705]	14.5+0.2s
# [3200/16000]	[L1: 5.2040]	14.6+0.0s
# [4800/16000]	[L1: 5.2433]	14.5+0.0s
# [6400/16000]	[L1: 5.1940]	14.2+0.0s
# [8000/16000]	[L1: 5.1550]	14.2+0.0s
# [9600/16000]	[L1: 5.1436]	14.4+0.0s
# [11200/16000]	[L1: 5.1464]	14.3+0.0s
# [12800/16000]	[L1: 5.1130]	14.3+0.0s
# [14400/16000]	[L1: 5.0949]	14.3+0.0s
# [16000/16000]	[L1: 5.1306]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 34.445 (Best: 34.445 @epoch 2)
# Total time: 46.21s, ave time: 4.62s
#
# [Epoch 3]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.6978]	14.3+0.2s
# [3200/16000]	[L1: 4.8686]	14.4+0.0s
# [4800/16000]	[L1: 4.8359]	14.5+0.0s
# [6400/16000]	[L1: 4.7996]	14.3+0.0s
# [8000/16000]	[L1: 4.7794]	14.2+0.0s
# [9600/16000]	[L1: 4.7372]	14.3+0.0s
# [11200/16000]	[L1: 4.7421]	14.4+0.0s
# [12800/16000]	[L1: 4.7183]	14.2+0.0s
# [14400/16000]	[L1: 4.7269]	14.1+0.0s
# [16000/16000]	[L1: 4.7402]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 34.823 (Best: 34.823 @epoch 3)
# Total time: 46.15s, ave time: 4.61s
#
# [Epoch 4]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.7563]	14.4+0.2s
# [3200/16000]	[L1: 4.6099]	14.3+0.0s
# [4800/16000]	[L1: 4.5810]	14.4+0.0s
# [6400/16000]	[L1: 4.5719]	14.5+0.0s
# [8000/16000]	[L1: 4.5882]	14.2+0.0s
# [9600/16000]	[L1: 4.6172]	14.3+0.0s
# [11200/16000]	[L1: 4.6338]	14.0+0.0s
# [12800/16000]	[L1: 4.6551]	14.6+0.0s
# [14400/16000]	[L1: 4.6466]	14.3+0.0s
# [16000/16000]	[L1: 4.6638]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 34.943 (Best: 34.943 @epoch 4)
# Total time: 46.18s, ave time: 4.62s
#
# [Epoch 5]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.7340]	14.5+0.2s
# [3200/16000]	[L1: 4.6118]	14.3+0.0s
# [4800/16000]	[L1: 4.5675]	14.2+0.0s
# [6400/16000]	[L1: 4.5679]	14.4+0.0s
# [8000/16000]	[L1: 4.5075]	14.2+0.0s
# [9600/16000]	[L1: 4.5558]	14.2+0.0s
# [11200/16000]	[L1: 4.5617]	14.2+0.0s
# [12800/16000]	[L1: 4.5568]	14.2+0.0s
# [14400/16000]	[L1: 4.5683]	14.2+0.0s
# [16000/16000]	[L1: 4.5698]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 34.985 (Best: 34.985 @epoch 5)
# Total time: 46.17s, ave time: 4.62s
#
# [Epoch 6]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.7270]	14.3+0.3s
# [3200/16000]	[L1: 4.6434]	14.6+0.0s
# [4800/16000]	[L1: 4.5928]	14.5+0.0s
# [6400/16000]	[L1: 4.5682]	14.8+0.0s
# [8000/16000]	[L1: 4.5582]	14.5+0.0s
# [9600/16000]	[L1: 4.5490]	14.4+0.0s
# [11200/16000]	[L1: 4.5279]	14.3+0.0s
# [12800/16000]	[L1: 4.5118]	14.4+0.0s
# [14400/16000]	[L1: 4.4983]	14.2+0.0s
# [16000/16000]	[L1: 4.4906]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 35.167 (Best: 35.167 @epoch 6)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 7]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.3247]	14.5+0.2s
# [3200/16000]	[L1: 4.4531]	14.2+0.0s
# [4800/16000]	[L1: 4.5310]	14.4+0.0s
# [6400/16000]	[L1: 4.5052]	14.4+0.0s
# [8000/16000]	[L1: 4.4906]	14.2+0.0s
# [9600/16000]	[L1: 4.4910]	14.2+0.0s
# [11200/16000]	[L1: 4.5041]	14.3+0.0s
# [12800/16000]	[L1: 4.4766]	14.2+0.0s
# [14400/16000]	[L1: 4.4722]	14.4+0.0s
# [16000/16000]	[L1: 4.4568]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 35.272 (Best: 35.272 @epoch 7)
# Total time: 46.22s, ave time: 4.62s
#
# [Epoch 8]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.2135]	14.5+0.3s
# [3200/16000]	[L1: 4.2361]	14.4+0.0s
# [4800/16000]	[L1: 4.2731]	14.3+0.0s
# [6400/16000]	[L1: 4.3588]	14.1+0.0s
# [8000/16000]	[L1: 4.3280]	14.4+0.0s
# [9600/16000]	[L1: 4.3068]	14.4+0.0s
# [11200/16000]	[L1: 4.2955]	14.4+0.0s
# [12800/16000]	[L1: 4.3060]	14.2+0.0s
# [14400/16000]	[L1: 4.2915]	14.3+0.0s
# [16000/16000]	[L1: 4.3045]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 35.621 (Best: 35.621 @epoch 8)
# Total time: 46.17s, ave time: 4.62s
#
# [Epoch 9]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.4390]	14.4+0.3s
# [3200/16000]	[L1: 4.2582]	14.3+0.0s
# [4800/16000]	[L1: 4.3066]	14.4+0.0s
# [6400/16000]	[L1: 4.2353]	14.3+0.0s
# [8000/16000]	[L1: 4.2159]	14.3+0.0s
# [9600/16000]	[L1: 4.2443]	14.2+0.0s
# [11200/16000]	[L1: 4.2345]	14.2+0.0s
# [12800/16000]	[L1: 4.2358]	14.2+0.0s
# [14400/16000]	[L1: 4.2452]	14.5+0.0s
# [16000/16000]	[L1: 4.2261]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 35.805 (Best: 35.805 @epoch 9)
# Total time: 46.18s, ave time: 4.62s
#
# [Epoch 10]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.2026]	14.6+0.2s
# [3200/16000]	[L1: 4.2570]	14.3+0.0s
# [4800/16000]	[L1: 4.2582]	14.2+0.0s
# [6400/16000]	[L1: 4.2836]	14.5+0.0s
# [8000/16000]	[L1: 4.2470]	14.4+0.0s
# [9600/16000]	[L1: 4.2392]	14.4+0.0s
# [11200/16000]	[L1: 4.2384]	14.6+0.0s
# [12800/16000]	[L1: 4.2724]	14.3+0.0s
# [14400/16000]	[L1: 4.2765]	14.3+0.0s
# [16000/16000]	[L1: 4.2680]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 35.948 (Best: 35.948 @epoch 10)
# Total time: 46.18s, ave time: 4.62s
#
# Saving model for epoch 10 to /content/drive/MyDrive/2516/RDN_50epoch_AblateCMLRL_Bicubic
# [Epoch 11]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.3582]	15.4+0.2s
# [3200/16000]	[L1: 4.1575]	14.4+0.0s
# [4800/16000]	[L1: 4.1476]	14.5+0.0s
# [6400/16000]	[L1: 4.1713]	14.4+0.0s
# [8000/16000]	[L1: 4.1581]	14.3+0.0s
# [9600/16000]	[L1: 4.1466]	14.3+0.0s
# [11200/16000]	[L1: 4.1201]	14.7+0.0s
# [12800/16000]	[L1: 4.1385]	14.6+0.0s
# [14400/16000]	[L1: 4.1510]	14.4+0.0s
# [16000/16000]	[L1: 4.1312]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.029 (Best: 36.029 @epoch 11)
# Total time: 46.17s, ave time: 4.62s
#
# [Epoch 12]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.3641]	14.5+0.2s
# [3200/16000]	[L1: 4.1686]	14.6+0.0s
# [4800/16000]	[L1: 4.1684]	14.7+0.0s
# [6400/16000]	[L1: 4.1438]	14.4+0.0s
# [8000/16000]	[L1: 4.1015]	14.4+0.0s
# [9600/16000]	[L1: 4.1111]	14.4+0.0s
# [11200/16000]	[L1: 4.1161]	14.2+0.0s
# [12800/16000]	[L1: 4.0903]	14.3+0.0s
# [14400/16000]	[L1: 4.0732]	14.3+0.0s
# [16000/16000]	[L1: 4.0892]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.022 (Best: 36.029 @epoch 11)
# Total time: 46.16s, ave time: 4.62s
#
# [Epoch 13]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.9522]	14.3+0.3s
# [3200/16000]	[L1: 3.9998]	14.4+0.0s
# [4800/16000]	[L1: 4.0398]	14.2+0.0s
# [6400/16000]	[L1: 4.0506]	14.5+0.0s
# [8000/16000]	[L1: 4.0600]	14.3+0.0s
# [9600/16000]	[L1: 4.0556]	14.4+0.0s
# [11200/16000]	[L1: 4.0761]	14.1+0.0s
# [12800/16000]	[L1: 4.0624]	14.5+0.0s
# [14400/16000]	[L1: 4.0586]	14.5+0.0s
# [16000/16000]	[L1: 4.0490]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.094 (Best: 36.094 @epoch 13)
# Total time: 46.15s, ave time: 4.62s
#
# [Epoch 14]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.0901]	14.7+0.2s
# [3200/16000]	[L1: 3.9527]	14.2+0.0s
# [4800/16000]	[L1: 3.9855]	14.3+0.0s
# [6400/16000]	[L1: 4.0390]	14.2+0.0s
# [8000/16000]	[L1: 4.0299]	14.1+0.0s
# [9600/16000]	[L1: 4.0104]	14.1+0.0s
# [11200/16000]	[L1: 4.0265]	14.1+0.0s
# [12800/16000]	[L1: 4.0201]	14.2+0.0s
# [14400/16000]	[L1: 4.0245]	14.4+0.0s
# [16000/16000]	[L1: 4.0083]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.215 (Best: 36.215 @epoch 14)
# Total time: 46.16s, ave time: 4.62s
#
# [Epoch 15]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.8750]	14.5+0.2s
# [3200/16000]	[L1: 3.8540]	14.3+0.0s
# [4800/16000]	[L1: 3.9002]	14.3+0.0s
# [6400/16000]	[L1: 3.9104]	14.5+0.0s
# [8000/16000]	[L1: 3.8979]	14.4+0.0s
# [9600/16000]	[L1: 3.8947]	14.1+0.0s
# [11200/16000]	[L1: 3.9204]	14.3+0.0s
# [12800/16000]	[L1: 3.9323]	14.4+0.0s
# [14400/16000]	[L1: 3.9328]	14.3+0.0s
# [16000/16000]	[L1: 3.9402]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 35.490 (Best: 36.215 @epoch 14)
# Total time: 46.18s, ave time: 4.62s
#
# [Epoch 16]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.0765]	14.3+0.2s
# [3200/16000]	[L1: 4.0139]	14.2+0.0s
# [4800/16000]	[L1: 3.9746]	14.3+0.0s
# [6400/16000]	[L1: 3.9990]	14.3+0.0s
# [8000/16000]	[L1: 4.0053]	14.2+0.0s
# [9600/16000]	[L1: 3.9915]	14.3+0.0s
# [11200/16000]	[L1: 3.9715]	14.2+0.0s
# [12800/16000]	[L1: 3.9764]	14.3+0.0s
# [14400/16000]	[L1: 3.9851]	14.2+0.0s
# [16000/16000]	[L1: 3.9935]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.269 (Best: 36.269 @epoch 16)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 17]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.0634]	14.4+0.2s
# [3200/16000]	[L1: 3.9785]	14.3+0.0s
# [4800/16000]	[L1: 3.9362]	14.3+0.0s
# [6400/16000]	[L1: 3.9063]	14.3+0.0s
# [8000/16000]	[L1: 3.9033]	14.1+0.0s
# [9600/16000]	[L1: 3.9038]	14.4+0.0s
# [11200/16000]	[L1: 3.9072]	14.4+0.0s
# [12800/16000]	[L1: 3.9097]	14.4+0.0s
# [14400/16000]	[L1: 3.8978]	14.3+0.0s
# [16000/16000]	[L1: 3.8922]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 35.849 (Best: 36.269 @epoch 16)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 18]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.0570]	14.4+0.2s
# [3200/16000]	[L1: 3.9965]	14.2+0.0s
# [4800/16000]	[L1: 3.9816]	14.3+0.0s
# [6400/16000]	[L1: 3.9302]	14.2+0.0s
# [8000/16000]	[L1: 3.9387]	14.5+0.0s
# [9600/16000]	[L1: 3.9267]	14.4+0.0s
# [11200/16000]	[L1: 3.9256]	14.4+0.0s
# [12800/16000]	[L1: 3.9403]	14.2+0.0s
# [14400/16000]	[L1: 3.9370]	14.3+0.0s
# [16000/16000]	[L1: 3.9416]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 35.579 (Best: 36.269 @epoch 16)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 19]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.9507]	14.5+0.2s
# [3200/16000]	[L1: 3.8739]	14.1+0.0s
# [4800/16000]	[L1: 4.0218]	14.3+0.0s
# [6400/16000]	[L1: 3.9972]	14.5+0.0s
# [8000/16000]	[L1: 3.9653]	14.3+0.0s
# [9600/16000]	[L1: 3.9928]	14.2+0.0s
# [11200/16000]	[L1: 3.9817]	14.2+0.0s
# [12800/16000]	[L1: 3.9843]	14.3+0.0s
# [14400/16000]	[L1: 3.9627]	14.1+0.0s
# [16000/16000]	[L1: 3.9443]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.244 (Best: 36.269 @epoch 16)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 20]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.0203]	14.9+0.2s
# [3200/16000]	[L1: 4.0421]	14.4+0.0s
# [4800/16000]	[L1: 4.0032]	14.5+0.0s
# [6400/16000]	[L1: 3.9423]	14.3+0.0s
# [8000/16000]	[L1: 3.9397]	14.3+0.0s
# [9600/16000]	[L1: 3.9161]	14.2+0.0s
# [11200/16000]	[L1: 3.8977]	14.2+0.0s
# [12800/16000]	[L1: 3.8770]	14.3+0.0s
# [14400/16000]	[L1: 3.8729]	14.3+0.0s
# [16000/16000]	[L1: 3.8847]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.374 (Best: 36.374 @epoch 20)
# Total time: 46.16s, ave time: 4.62s
#
# Saving model for epoch 20 to /content/drive/MyDrive/2516/RDN_50epoch_AblateCMLRL_Bicubic
# [Epoch 21]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 4.0100]	15.3+0.2s
# [3200/16000]	[L1: 3.8699]	14.4+0.0s
# [4800/16000]	[L1: 3.9492]	14.4+0.0s
# [6400/16000]	[L1: 3.9179]	14.2+0.0s
# [8000/16000]	[L1: 3.9035]	14.2+0.0s
# [9600/16000]	[L1: 3.9138]	14.3+0.0s
# [11200/16000]	[L1: 3.9054]	14.1+0.0s
# [12800/16000]	[L1: 3.8850]	14.3+0.0s
# [14400/16000]	[L1: 3.8838]	14.2+0.0s
# [16000/16000]	[L1: 3.8584]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.117 (Best: 36.374 @epoch 20)
# Total time: 46.17s, ave time: 4.62s
#
# [Epoch 22]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7637]	14.4+0.2s
# [3200/16000]	[L1: 3.8361]	14.1+0.0s
# [4800/16000]	[L1: 3.8615]	14.2+0.0s
# [6400/16000]	[L1: 3.9004]	14.2+0.0s
# [8000/16000]	[L1: 3.8828]	14.2+0.0s
# [9600/16000]	[L1: 3.8804]	14.0+0.0s
# [11200/16000]	[L1: 3.8996]	14.3+0.0s
# [12800/16000]	[L1: 3.8975]	14.3+0.0s
# [14400/16000]	[L1: 3.9064]	14.3+0.0s
# [16000/16000]	[L1: 3.8890]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.405 (Best: 36.405 @epoch 22)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 23]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.8277]	14.3+0.2s
# [3200/16000]	[L1: 3.8081]	14.1+0.0s
# [4800/16000]	[L1: 3.7785]	14.4+0.0s
# [6400/16000]	[L1: 3.8204]	14.3+0.0s
# [8000/16000]	[L1: 3.8453]	14.3+0.0s
# [9600/16000]	[L1: 3.8527]	14.4+0.0s
# [11200/16000]	[L1: 3.8902]	14.2+0.0s
# [12800/16000]	[L1: 3.9037]	14.3+0.0s
# [14400/16000]	[L1: 3.8948]	13.9+0.0s
# [16000/16000]	[L1: 3.8812]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.210 (Best: 36.405 @epoch 22)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 24]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7576]	14.3+0.2s
# [3200/16000]	[L1: 3.7850]	14.4+0.0s
# [4800/16000]	[L1: 3.7936]	14.4+0.0s
# [6400/16000]	[L1: 3.8081]	14.2+0.0s
# [8000/16000]	[L1: 3.8182]	14.2+0.0s
# [9600/16000]	[L1: 3.8604]	14.2+0.0s
# [11200/16000]	[L1: 3.8504]	14.2+0.0s
# [12800/16000]	[L1: 3.8411]	14.2+0.0s
# [14400/16000]	[L1: 3.8442]	14.2+0.0s
# [16000/16000]	[L1: 3.8439]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.405 (Best: 36.405 @epoch 24)
# Total time: 46.15s, ave time: 4.61s
#
# [Epoch 25]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.9785]	14.4+0.2s
# [3200/16000]	[L1: 3.8583]	14.3+0.0s
# [4800/16000]	[L1: 3.8658]	14.3+0.0s
# [6400/16000]	[L1: 3.8441]	14.4+0.0s
# [8000/16000]	[L1: 3.8756]	14.0+0.0s
# [9600/16000]	[L1: 3.8627]	14.2+0.0s
# [11200/16000]	[L1: 3.8939]	14.4+0.0s
# [12800/16000]	[L1: 3.8959]	14.2+0.0s
# [14400/16000]	[L1: 3.9027]	14.3+0.0s
# [16000/16000]	[L1: 3.8994]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.210 (Best: 36.405 @epoch 24)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 26]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.8958]	14.5+0.2s
# [3200/16000]	[L1: 3.8366]	14.3+0.0s
# [4800/16000]	[L1: 3.8914]	14.1+0.0s
# [6400/16000]	[L1: 3.8344]	14.1+0.0s
# [8000/16000]	[L1: 3.8230]	14.4+0.0s
# [9600/16000]	[L1: 3.8348]	14.3+0.0s
# [11200/16000]	[L1: 3.8250]	14.1+0.0s
# [12800/16000]	[L1: 3.8208]	14.2+0.0s
# [14400/16000]	[L1: 3.8389]	14.5+0.0s
# [16000/16000]	[L1: 3.8403]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.202 (Best: 36.405 @epoch 24)
# Total time: 46.16s, ave time: 4.62s
#
# [Epoch 27]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7648]	14.3+0.3s
# [3200/16000]	[L1: 3.7655]	14.1+0.0s
# [4800/16000]	[L1: 3.7561]	14.1+0.0s
# [6400/16000]	[L1: 3.8131]	14.3+0.0s
# [8000/16000]	[L1: 3.8239]	14.2+0.0s
# [9600/16000]	[L1: 3.8210]	14.4+0.0s
# [11200/16000]	[L1: 3.8314]	14.4+0.0s
# [12800/16000]	[L1: 3.8130]	14.3+0.0s
# [14400/16000]	[L1: 3.7915]	14.3+0.0s
# [16000/16000]	[L1: 3.8038]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.357 (Best: 36.405 @epoch 24)
# Total time: 46.20s, ave time: 4.62s
#
# [Epoch 28]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.8303]	14.6+0.3s
# [3200/16000]	[L1: 3.8075]	14.6+0.0s
# [4800/16000]	[L1: 3.7710]	14.1+0.0s
# [6400/16000]	[L1: 3.7668]	14.3+0.0s
# [8000/16000]	[L1: 3.8115]	14.2+0.0s
# [9600/16000]	[L1: 3.8104]	14.2+0.0s
# [11200/16000]	[L1: 3.7825]	14.2+0.0s
# [12800/16000]	[L1: 3.7966]	14.3+0.0s
# [14400/16000]	[L1: 3.8108]	14.5+0.0s
# [16000/16000]	[L1: 3.8206]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.211 (Best: 36.405 @epoch 24)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 29]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.5744]	14.4+0.2s
# [3200/16000]	[L1: 3.6723]	14.4+0.0s
# [4800/16000]	[L1: 3.7872]	14.3+0.0s
# [6400/16000]	[L1: 3.7637]	14.4+0.0s
# [8000/16000]	[L1: 3.7542]	14.4+0.0s
# [9600/16000]	[L1: 3.7538]	14.4+0.0s
# [11200/16000]	[L1: 3.7722]	14.3+0.0s
# [12800/16000]	[L1: 3.7635]	14.5+0.0s
# [14400/16000]	[L1: 3.7542]	14.3+0.0s
# [16000/16000]	[L1: 3.7572]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.414 (Best: 36.414 @epoch 29)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 30]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7296]	14.6+0.3s
# [3200/16000]	[L1: 3.7677]	14.3+0.0s
# [4800/16000]	[L1: 3.7682]	14.4+0.0s
# [6400/16000]	[L1: 3.7545]	14.3+0.0s
# [8000/16000]	[L1: 3.7633]	14.2+0.0s
# [9600/16000]	[L1: 3.7903]	14.5+0.0s
# [11200/16000]	[L1: 3.7963]	14.4+0.0s
# [12800/16000]	[L1: 3.8139]	14.2+0.0s
# [14400/16000]	[L1: 3.8252]	14.3+0.0s
# [16000/16000]	[L1: 3.8216]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.239 (Best: 36.414 @epoch 29)
# Total time: 46.12s, ave time: 4.61s
#
# Saving model for epoch 30 to /content/drive/MyDrive/2516/RDN_50epoch_AblateCMLRL_Bicubic
# [Epoch 31]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7535]	15.4+0.3s
# [3200/16000]	[L1: 3.7374]	14.3+0.0s
# [4800/16000]	[L1: 3.7374]	14.4+0.0s
# [6400/16000]	[L1: 3.7992]	14.1+0.0s
# [8000/16000]	[L1: 3.8161]	14.3+0.0s
# [9600/16000]	[L1: 3.8119]	14.3+0.0s
# [11200/16000]	[L1: 3.8113]	14.1+0.0s
# [12800/16000]	[L1: 3.7949]	14.2+0.0s
# [14400/16000]	[L1: 3.7949]	14.2+0.0s
# [16000/16000]	[L1: 3.7762]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.471 (Best: 36.471 @epoch 31)
# Total time: 46.18s, ave time: 4.62s
#
# [Epoch 32]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7633]	14.3+0.3s
# [3200/16000]	[L1: 3.7475]	14.0+0.0s
# [4800/16000]	[L1: 3.7631]	14.1+0.0s
# [6400/16000]	[L1: 3.7588]	14.4+0.0s
# [8000/16000]	[L1: 3.7777]	14.3+0.0s
# [9600/16000]	[L1: 3.8184]	14.4+0.0s
# [11200/16000]	[L1: 3.8244]	14.1+0.0s
# [12800/16000]	[L1: 3.8252]	14.0+0.0s
# [14400/16000]	[L1: 3.8139]	14.0+0.0s
# [16000/16000]	[L1: 3.8010]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.470 (Best: 36.471 @epoch 31)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 33]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6295]	14.4+0.2s
# [3200/16000]	[L1: 3.7208]	14.2+0.0s
# [4800/16000]	[L1: 3.6999]	13.9+0.0s
# [6400/16000]	[L1: 3.7231]	14.3+0.0s
# [8000/16000]	[L1: 3.7185]	14.1+0.0s
# [9600/16000]	[L1: 3.7466]	14.3+0.0s
# [11200/16000]	[L1: 3.7492]	14.1+0.0s
# [12800/16000]	[L1: 3.7567]	14.2+0.0s
# [14400/16000]	[L1: 3.7478]	14.1+0.0s
# [16000/16000]	[L1: 3.7567]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.490 (Best: 36.490 @epoch 33)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 34]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6687]	14.2+0.2s
# [3200/16000]	[L1: 3.8055]	14.3+0.0s
# [4800/16000]	[L1: 3.8660]	14.0+0.0s
# [6400/16000]	[L1: 3.8160]	14.1+0.0s
# [8000/16000]	[L1: 3.8011]	14.0+0.0s
# [9600/16000]	[L1: 3.8327]	14.2+0.0s
# [11200/16000]	[L1: 3.8185]	14.0+0.0s
# [12800/16000]	[L1: 3.8112]	14.2+0.0s
# [14400/16000]	[L1: 3.8094]	14.2+0.0s
# [16000/16000]	[L1: 3.8176]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.460 (Best: 36.490 @epoch 33)
# Total time: 46.16s, ave time: 4.62s
#
# [Epoch 35]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.8622]	14.2+0.2s
# [3200/16000]	[L1: 3.9242]	14.1+0.0s
# [4800/16000]	[L1: 3.8442]	14.3+0.0s
# [6400/16000]	[L1: 3.8227]	14.1+0.0s
# [8000/16000]	[L1: 3.7791]	14.0+0.0s
# [9600/16000]	[L1: 3.7768]	14.0+0.0s
# [11200/16000]	[L1: 3.7482]	14.0+0.0s
# [12800/16000]	[L1: 3.7661]	14.1+0.0s
# [14400/16000]	[L1: 3.7728]	14.2+0.0s
# [16000/16000]	[L1: 3.7537]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 35.995 (Best: 36.490 @epoch 33)
# Total time: 46.14s, ave time: 4.61s
#
# [Epoch 36]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7109]	14.2+0.2s
# [3200/16000]	[L1: 3.7675]	14.3+0.0s
# [4800/16000]	[L1: 3.8244]	14.1+0.0s
# [6400/16000]	[L1: 3.8325]	14.3+0.0s
# [8000/16000]	[L1: 3.8167]	13.9+0.0s
# [9600/16000]	[L1: 3.7810]	13.9+0.0s
# [11200/16000]	[L1: 3.7864]	13.9+0.0s
# [12800/16000]	[L1: 3.7813]	14.1+0.0s
# [14400/16000]	[L1: 3.7823]	14.0+0.0s
# [16000/16000]	[L1: 3.7666]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.485 (Best: 36.490 @epoch 33)
# Total time: 46.10s, ave time: 4.61s
#
# [Epoch 37]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6830]	14.1+0.2s
# [3200/16000]	[L1: 3.7441]	14.0+0.0s
# [4800/16000]	[L1: 3.7716]	14.3+0.0s
# [6400/16000]	[L1: 3.7570]	14.1+0.0s
# [8000/16000]	[L1: 3.7453]	14.1+0.0s
# [9600/16000]	[L1: 3.7547]	14.0+0.0s
# [11200/16000]	[L1: 3.7588]	14.1+0.0s
# [12800/16000]	[L1: 3.7520]	14.3+0.0s
# [14400/16000]	[L1: 3.7505]	14.3+0.0s
# [16000/16000]	[L1: 3.7590]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.474 (Best: 36.490 @epoch 33)
# Total time: 46.18s, ave time: 4.62s
#
# [Epoch 38]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6858]	14.4+0.2s
# [3200/16000]	[L1: 3.6900]	14.3+0.0s
# [4800/16000]	[L1: 3.6583]	14.3+0.0s
# [6400/16000]	[L1: 3.6400]	14.0+0.0s
# [8000/16000]	[L1: 3.6743]	14.3+0.0s
# [9600/16000]	[L1: 3.6975]	14.3+0.0s
# [11200/16000]	[L1: 3.7232]	14.4+0.0s
# [12800/16000]	[L1: 3.7339]	14.3+0.0s
# [14400/16000]	[L1: 3.7230]	14.3+0.0s
# [16000/16000]	[L1: 3.7302]	13.9+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.104 (Best: 36.490 @epoch 33)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 39]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7665]	14.1+0.2s
# [3200/16000]	[L1: 3.7430]	14.2+0.0s
# [4800/16000]	[L1: 3.7167]	14.0+0.0s
# [6400/16000]	[L1: 3.7587]	14.1+0.0s
# [8000/16000]	[L1: 3.7298]	14.1+0.0s
# [9600/16000]	[L1: 3.7278]	14.2+0.0s
# [11200/16000]	[L1: 3.7167]	14.1+0.0s
# [12800/16000]	[L1: 3.7126]	14.3+0.0s
# [14400/16000]	[L1: 3.6991]	14.3+0.0s
# [16000/16000]	[L1: 3.6813]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.446 (Best: 36.490 @epoch 33)
# Total time: 46.16s, ave time: 4.62s
#
# [Epoch 40]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7755]	14.3+0.2s
# [3200/16000]	[L1: 3.7558]	14.3+0.0s
# [4800/16000]	[L1: 3.7724]	14.0+0.0s
# [6400/16000]	[L1: 3.7595]	14.1+0.0s
# [8000/16000]	[L1: 3.7159]	14.0+0.0s
# [9600/16000]	[L1: 3.7300]	14.0+0.0s
# [11200/16000]	[L1: 3.7312]	14.0+0.0s
# [12800/16000]	[L1: 3.7314]	14.4+0.0s
# [14400/16000]	[L1: 3.7331]	14.0+0.0s
# [16000/16000]	[L1: 3.7358]	14.1+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.579 (Best: 36.579 @epoch 40)
# Total time: 46.13s, ave time: 4.61s
#
# Saving model for epoch 40 to /content/drive/MyDrive/2516/RDN_50epoch_AblateCMLRL_Bicubic
# [Epoch 41]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6765]	15.1+0.2s
# [3200/16000]	[L1: 3.7694]	14.0+0.0s
# [4800/16000]	[L1: 3.8077]	14.1+0.0s
# [6400/16000]	[L1: 3.7842]	14.1+0.0s
# [8000/16000]	[L1: 3.7529]	14.1+0.0s
# [9600/16000]	[L1: 3.7240]	13.9+0.0s
# [11200/16000]	[L1: 3.7036]	14.1+0.0s
# [12800/16000]	[L1: 3.7115]	14.1+0.0s
# [14400/16000]	[L1: 3.7115]	14.1+0.0s
# [16000/16000]	[L1: 3.7240]	13.9+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.100 (Best: 36.579 @epoch 40)
# Total time: 46.11s, ave time: 4.61s
#
# [Epoch 42]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6245]	14.1+0.2s
# [3200/16000]	[L1: 3.6753]	14.2+0.0s
# [4800/16000]	[L1: 3.6640]	13.9+0.0s
# [6400/16000]	[L1: 3.6790]	14.0+0.0s
# [8000/16000]	[L1: 3.6672]	14.3+0.0s
# [9600/16000]	[L1: 3.6757]	14.1+0.0s
# [11200/16000]	[L1: 3.6727]	14.5+0.0s
# [12800/16000]	[L1: 3.6980]	14.2+0.0s
# [14400/16000]	[L1: 3.7124]	14.2+0.0s
# [16000/16000]	[L1: 3.7262]	14.0+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.569 (Best: 36.579 @epoch 40)
# Total time: 46.13s, ave time: 4.61s
#
# [Epoch 43]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6899]	14.5+0.2s
# [3200/16000]	[L1: 3.6737]	14.4+0.0s
# [4800/16000]	[L1: 3.7471]	14.1+0.0s
# [6400/16000]	[L1: 3.7601]	14.2+0.0s
# [8000/16000]	[L1: 3.7497]	14.2+0.0s
# [9600/16000]	[L1: 3.7541]	14.4+0.0s
# [11200/16000]	[L1: 3.7457]	14.1+0.0s
# [12800/16000]	[L1: 3.7367]	14.3+0.0s
# [14400/16000]	[L1: 3.7231]	14.3+0.0s
# [16000/16000]	[L1: 3.7321]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.254 (Best: 36.579 @epoch 40)
# Total time: 46.10s, ave time: 4.61s
#
# [Epoch 44]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.8444]	14.3+0.2s
# [3200/16000]	[L1: 3.8111]	14.1+0.0s
# [4800/16000]	[L1: 3.7829]	14.4+0.0s
# [6400/16000]	[L1: 3.7588]	14.1+0.0s
# [8000/16000]	[L1: 3.7427]	14.3+0.0s
# [9600/16000]	[L1: 3.7117]	14.3+0.0s
# [11200/16000]	[L1: 3.6773]	14.0+0.0s
# [12800/16000]	[L1: 3.6774]	14.0+0.0s
# [14400/16000]	[L1: 3.6818]	14.1+0.0s
# [16000/16000]	[L1: 3.6877]	13.9+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.398 (Best: 36.579 @epoch 40)
# Total time: 46.17s, ave time: 4.62s
#
# [Epoch 45]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.9326]	14.3+0.2s
# [3200/16000]	[L1: 3.7259]	14.1+0.0s
# [4800/16000]	[L1: 3.7847]	14.2+0.0s
# [6400/16000]	[L1: 3.7589]	14.4+0.0s
# [8000/16000]	[L1: 3.7453]	14.2+0.0s
# [9600/16000]	[L1: 3.7490]	14.1+0.0s
# [11200/16000]	[L1: 3.7340]	14.2+0.0s
# [12800/16000]	[L1: 3.7238]	14.4+0.0s
# [14400/16000]	[L1: 3.7175]	14.4+0.0s
# [16000/16000]	[L1: 3.7104]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 35.140 (Best: 36.579 @epoch 40)
# Total time: 46.15s, ave time: 4.61s
#
# [Epoch 46]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7274]	14.3+0.2s
# [3200/16000]	[L1: 3.7936]	14.2+0.0s
# [4800/16000]	[L1: 3.7508]	14.2+0.0s
# [6400/16000]	[L1: 3.7179]	14.2+0.0s
# [8000/16000]	[L1: 3.7002]	14.2+0.0s
# [9600/16000]	[L1: 3.7006]	14.3+0.0s
# [11200/16000]	[L1: 3.7221]	14.3+0.0s
# [12800/16000]	[L1: 3.7260]	14.1+0.0s
# [14400/16000]	[L1: 3.7285]	13.9+0.0s
# [16000/16000]	[L1: 3.7104]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.537 (Best: 36.579 @epoch 40)
# Total time: 46.12s, ave time: 4.61s
#
# [Epoch 47]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6605]	14.5+0.2s
# [3200/16000]	[L1: 3.7557]	14.2+0.0s
# [4800/16000]	[L1: 3.6638]	14.4+0.0s
# [6400/16000]	[L1: 3.7293]	14.2+0.0s
# [8000/16000]	[L1: 3.7366]	14.4+0.0s
# [9600/16000]	[L1: 3.7142]	14.3+0.0s
# [11200/16000]	[L1: 3.7029]	14.5+0.0s
# [12800/16000]	[L1: 3.7153]	14.4+0.0s
# [14400/16000]	[L1: 3.7266]	14.5+0.0s
# [16000/16000]	[L1: 3.7245]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.376 (Best: 36.579 @epoch 40)
# Total time: 46.11s, ave time: 4.61s
#
# [Epoch 48]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7501]	14.5+0.3s
# [3200/16000]	[L1: 3.6814]	14.4+0.0s
# [4800/16000]	[L1: 3.6785]	14.4+0.0s
# [6400/16000]	[L1: 3.6527]	14.4+0.0s
# [8000/16000]	[L1: 3.6464]	14.3+0.0s
# [9600/16000]	[L1: 3.6653]	14.5+0.0s
# [11200/16000]	[L1: 3.6974]	14.2+0.0s
# [12800/16000]	[L1: 3.6855]	14.4+0.0s
# [14400/16000]	[L1: 3.6891]	14.4+0.0s
# [16000/16000]	[L1: 3.6929]	14.2+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.482 (Best: 36.579 @epoch 40)
# Total time: 46.10s, ave time: 4.61s
#
# [Epoch 49]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.7510]	14.5+0.2s
# [3200/16000]	[L1: 3.8759]	14.4+0.0s
# [4800/16000]	[L1: 3.8213]	14.1+0.0s
# [6400/16000]	[L1: 3.7976]	14.4+0.0s
# [8000/16000]	[L1: 3.7921]	14.4+0.0s
# [9600/16000]	[L1: 3.7957]	14.4+0.0s
# [11200/16000]	[L1: 3.7614]	14.2+0.0s
# [12800/16000]	[L1: 3.7437]	14.3+0.0s
# [14400/16000]	[L1: 3.7490]	14.3+0.0s
# [16000/16000]	[L1: 3.7411]	14.4+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.62s/it]
# [DIV2K x2]	PSNR: 36.527 (Best: 36.579 @epoch 40)
# Total time: 46.18s, ave time: 4.62s
#
# [Epoch 50]	Learning rate: 1.00e-4
# [1600/16000]	[L1: 3.6427]	14.3+0.2s
# [3200/16000]	[L1: 3.6444]	14.3+0.0s
# [4800/16000]	[L1: 3.6749]	14.4+0.0s
# [6400/16000]	[L1: 3.6932]	14.2+0.0s
# [8000/16000]	[L1: 3.7276]	14.2+0.0s
# [9600/16000]	[L1: 3.7157]	14.2+0.0s
# [11200/16000]	[L1: 3.7158]	14.2+0.0s
# [12800/16000]	[L1: 3.7090]	14.6+0.0s
# [14400/16000]	[L1: 3.7018]	14.5+0.0s
# [16000/16000]	[L1: 3.7042]	14.3+0.0s
#
# Evaluation:
# 100%|███████████████████████████████████████████| 10/10 [00:46<00:00,  4.61s/it]
# [DIV2K x2]	PSNR: 36.615 (Best: 36.615 @epoch 50)
# Total time: 46.11s, ave time: 4.61s
#
# Saving model for epoch 50 to /content/drive/MyDrive/2516/RDN_50epoch_AblateCMLRL_Bicubic

# %% [markdown]
# ## Resume Training

# %%
#!python main.py --resume -1 --load {CODE_DIR}/SR/BI/{experiment_name} --ext_save_path {GDRIVE}/{experiment_name} --save_model_every 10 --RDNconfig C --dir_data ../../.. --ext sep --scale 2 --model RDN --epochs 50 --patch_size 32 --chop --save {experiment_name} --save_results
# Out:
# Making model...
# Traceback (most recent call last):
#   File "main.py", line 14, in <module>
#     model = model.Model(args, checkpoint)
#   File "/content/SingleImageSuperResolution/TestCode/code/model/__init__.py", line 34, in __init__
#     cpu=args.cpu
#   File "/content/SingleImageSuperResolution/TestCode/code/model/__init__.py", line 96, in load
#     **kwargs
#   File "/usr/local/lib/python3.7/dist-packages/torch/serialization.py", line 382, in load
#     f = open(f, 'rb')
# FileNotFoundError: [Errno 2] No such file or directory: '/content/SingleImageSuperResolution/TestCode/SR/BI/RDN/model/model_latest.pt'

# %% [markdown]
# ## Test Trained Model

# %% [markdown]
# Load model from checkpoint

# %%
cd {CODE_DIR}/code
# Out:
# /content/SingleImageSuperResolution/TestCode/code

# %%
# !python main.py --data_test MyImage --scale 2 --RDNconfig C --model RDN --n_feats 64 --pre_train {CODE_DIR}/SR/BI/{experiment_name}/model/model_best.pt --test_only --save_results --chop --save {experiment_name}Test --testpath ../LR/LRBI --testset Set5
# Out:
# Making model...
# Loading model from /content/SingleImageSuperResolution/TestCode/SR/BI/RDN_50epoch_AblateCMLRL_Bicubic/model/model_best.pt
#
# Evaluation:
# 100%|█████████████████████████████████████████████| 5/5 [00:01<00:00,  2.92it/s]
# [MyImage x2]	PSNR: 37.501 (Best: 37.501 @epoch 1)
# Total time: 1.72s, ave time: 0.34s

# %% [markdown]
# # Save Model

# %%
mkdir /content/{experiment_name}

# %%
cp -r {CODE_DIR}/SR/BI/{experiment_name}/* /content/{experiment_name}/

# %%
cd /content/
# Out:
# /content

# %%
# !zip -r -q {experiment_name}.zip {experiment_name}

# %%
cp {experiment_name}.zip {GDRIVE}
